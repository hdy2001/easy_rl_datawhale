# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from env.gridworld_env import CliffWalkingWapper

# %%
class Config:
    def __init__(self):
        self.policy_lr = 0.01
        self.gamma = 0.8
        self.train_eps = 500
        self.start_epsilon = 0.9
        self.end_epsilon = 0.1
        self.decay_epsilon = 300
cfg = Config()

# %%
"""Agent"""
class QLearning:
    def __init__(self, state_dim, action_dim, cfg):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.lr = cfg.policy_lr
        self.gamma = cfg.gamma
        self.start_epsilon = cfg.start_epsilon
        self.end_epsilon = cfg.end_epsilon
        self.decay_epsilon = cfg.decay_epsilon
        self.count = 0
        self.q_table = np.zeros((self.state_dim, self.action_dim)) # (state_dim, action_dim)
    def update(self, state, action, reward, next_state, done):
        if done:
            self.q_table[state][action] = reward
            return
        q_value = self.q_table[state][action] 
        delta = reward + self.gamma * np.max(self.q_table[next_state]) - q_value
        self.q_table[state][action] += self.lr * delta 
        return
    def choose_action(self, state):
        self.count += 1
        epsilon = self.end_epsilon + (self.start_epsilon - self.end_epsilon) * \
            np.exp(-1. * self.count / self.decay_epsilon)
        if np.random.uniform(0, 1) > epsilon:
            action = np.argmax(self.q_table[state])
        else:
            action = np.random.choice(self.action_dim) 
        return action # 0~3

# %%
'''初始化环境'''  
env = gym.make("CliffWalking-v0")  # 0 up, 1 right, 2 down, 3 left
env = CliffWalkingWapper(env)
agent = QLearning(
    state_dim=env.observation_space.n,
    action_dim=env.action_space.n,
    cfg=cfg
    )
rewards = []  
ma_rewards = [] # moving average reward
for i_ep in range(cfg.train_eps): # train_eps: 训练的最大episodes数
    ep_reward = 0  # 记录每个episode的reward
    state = env.reset()  # 重置环境, 重新开一局（即开始新的一个episode）
    while True:
        action = agent.choose_action(state)  # 根据算法选择一个动作
        next_state, reward, done, _ = env.step(action)  # 与环境进行一次动作交互
        agent.update(state, action, reward, next_state, done)  # Q-learning算法更新
        state = next_state  # 存储上一个观察值
        ep_reward += reward
        if done:
            break
    rewards.append(ep_reward)
    if ma_rewards:
        ma_rewards.append(ma_rewards[-1]*0.9+ep_reward*0.1)
    else:
        ma_rewards.append(ep_reward)
    print("Episode:{}/{}: reward:{:.1f}".format(i_ep+1, cfg.train_eps,ep_reward))
# Out:
# Episode:1/500: reward:-1947.0
# Episode:2/500: reward:-2749.0
# Episode:3/500: reward:-7401.0
# Episode:4/500: reward:-3213.0
# Episode:5/500: reward:-7406.0
# Episode:6/500: reward:-7611.0
# Episode:7/500: reward:-366.0
# Episode:8/500: reward:-241.0
# Episode:9/500: reward:-499.0
# Episode:10/500: reward:-425.0
# Episode:11/500: reward:-766.0
# Episode:12/500: reward:-359.0
# Episode:13/500: reward:-795.0
# Episode:14/500: reward:-668.0
# Episode:15/500: reward:-79.0
# Episode:16/500: reward:-406.0
# Episode:17/500: reward:-518.0
# Episode:18/500: reward:-565.0
# Episode:19/500: reward:-443.0
# Episode:440/500: reward:-40.0
# Episode:441/500: reward:-61.0
# Episode:442/500: reward:-44.0
# Episode:443/500: reward:-163.0
# Episode:444/500: reward:-57.0
# Episode:445/500: reward:-58.0
# Episode:446/500: reward:-36.0
# Episode:447/500: reward:-174.0
# Episode:448/500: reward:-464.0
# Episode:449/500: reward:-45.0
# Episode:450/500: reward:-37.0
# Episode:451/500: reward:-169.0
# Episode:452/500: reward:-65.0
# Episode:453/500: reward:-184.0
# Episode:454/500: reward:-151.0
# Episode:455/500: reward:-180.0
# Episode:456/500: reward:-67.0
# Episode:457/500: reward:-169.0
# Episode:458/500: reward:-65.0
# Episode:459/500: reward:-290.0
# Episode:460/500: reward:-39.0
# Episode:461/500: reward:-73.0
# Episode:462/500: reward:-290.0
# Episode:463/500: reward:-29.0
# Episode:464/500: reward:-58.0
# Episode:465/500: reward:-200.0
# Episode:466/500: reward:-26.0
# Episode:467/500: reward:-31.0
# Episode:468/500: reward:-63.0
# Episode:469/500: reward:-59.0
# Episode:470/500: reward:-61.0
# Episode:471/500: reward:-287.0
# Episode:472/500: reward:-46.0
# Episode:473/500: reward:-163.0
# Episode:474/500: reward:-176.0
# Episode:475/500: reward:-73.0
# Episode:476/500: reward:-42.0
# Episode:477/500: reward:-37.0
# Episode:478/500: reward:-183.0
# Episode:479/500: reward:-32.0
# Episode:480/500: reward:-110.0
# Episode:481/500: reward:-32.0
# Episode:482/500: reward:-157.0
# Episode:483/500: reward:-38.0
# Episode:484/500: reward:-53.0
# Episode:485/500: reward:-44.0
# Episode:486/500: reward:-45.0
# Episode:487/500: reward:-71.0
# Episode:488/500: reward:-179.0
# Episode:489/500: reward:-429.0
# Episode:490/500: reward:-49.0
# Episode:491/500: reward:-74.0
# Episode:492/500: reward:-142.0
# Episode:493/500: reward:-204.0
# Episode:494/500: reward:-23.0
# Episode:495/500: reward:-75.0
# Episode:496/500: reward:-32.0
# Episode:497/500: reward:-58.0
# Episode:498/500: reward:-45.0
# Episode:499/500: reward:-32.0
# Episode:500/500: reward:-96.0

# %%
"""Plot"""
def Plot():
    x, y = np.arange(cfg.train_eps), rewards
    plt.plot(x, y)
    plt.title("rewards of Q-learning")
    plt.xlabel("episodes")
    plt.ylabel("rewards")
    plt.show()
    y = ma_rewards
    plt.plot(x, y)
    plt.xlabel("episodes")
    plt.ylabel("moving_average_rewards")
    plt.title("moving_average_rewards of Q-learning")
    plt.show()
    
Plot()

# %%
"""Test"""
state = env.reset()
test_reward = 0
while True:
    action = agent.choose_action(state)  # 根据算法选择一个动作
    next_state, reward, done, _ = env.step(action)  # 与环境进行一次动作交互
    agent.update(state, action, reward, next_state, done)  # Q-learning算法更新
    state = next_state  # 存储上一个观察值
    test_reward += reward
    if done:
        break
print("Test Rewards:%f"%test_reward)
# Out:
# Test Rewards:-52.000000
